# %%
import pandas as pd

df1 = pd.read_excel("./매각_.xlsx")
df1.head()
# Out:
#    Unnamed: 0        기본                 주소    상세주소  A   카맵 land  나라  \
# 0           0      카페밤비  서울 마포구 망원동 57-498     NaN  A  카카오  랜드북  나라
# 1           1      삼우빌딩    서울 강남구 개포동 1228     NaN  A  카카오  랜드북  나라
# 2           2  룩홈게스트하우스  서울 중구 남산동2가 27-12     -21  A  카카오  랜드북  나라
# 3           3   무신사스탠다드   서울 중구 남대문로2가 5-3  199-15  A  카카오  랜드북  나라
# 4           4      수환빌딩   서울 강남구 논현동 33-15     NaN  A  카카오  랜드북  나라
#
#              주변역    입금가(만원)  ...                         고객  \
# 0       망원역(6호선)    195,000  ...               이재남 691015-2
# 1  양재시민의숲역(신분당선)  1,200,000  ...  차동주 580926-1 박숙향 610315-2
# 2       명동역(4호선)    500,000  ...    박주연8903302,박세희900912-2,
# 3            NaN          0  ...         디디아이명동엔위탁관리부동산투자회사
# 4       학동역(7호선)  1,600,000  ...                 손민홍 700117
#
#                                  핸드폰  이메일         회사전화 자택전화  \
# 0                                NaN  NaN          NaN  NaN
# 1                  박숙향 010-7270-9416  NaN          NaN  NaN
# ...

# %%
df2 = pd.read_excel("./보류.xlsx")
df2.head()
# Out:
#    Unnamed: 0    기본                    주소 상세주소  A   카맵 land  나라  \
# 0           0  송연빌딩       서울 송파구 송파동 89-2  NaN  A  카카오  랜드북  나라
# 1           1  서경빌딩    서울 성북구 보문동2가 137-1  NaN  A  카카오  랜드북  나라
# 2           2   초원빌      서울 성북구 석관동 180-8  NaN  A  카카오  랜드북  나라
# 3           3  서문빌딩     서울 마포구 서교동 368-22  NaN  A  카카오  랜드북  나라
# 4           4  장고키친  서울 성동구 성수동1가 668-140  NaN  A  카카오  랜드북  나라
#
#                   주변역    입금가(만원)  ...                         고객  \
# 0       석촌역(8호선, 9호선)  1,500,000  ...               김용진 600719-1
# 1     보문역(6호선, 우이신설선)    400,000  ...               이인완 690819-2
# 2      석계역 (1호선, 6호선)    185,000  ...               임지현 660909-2
# 3      합정역 (2호선, 6호선)  3,300,000  ...            주식회사동희 130111-0
# 4  뚝섬역(2호선) 서울숲역(분당선)    700,000  ...  강원애 481108-2 김지연 740812-2
#
#                   핸드폰            이메일                               회사전화  \
# 0   김용진 010-7397-1497            NaN                                NaN
# ...

# %%
df3 = pd.read_excel("./완료1_.xlsx")
df3.head()
# Out:
#    Unnamed: 0          기본                   주소 상세주소  A   카맵 land  나라  \
# 0           0       상암바라라      서울 마포구 상암동 1452  NaN  A  카카오  랜드북  나라
# 1           1   공릉역신축부지16    서울 노원구 공릉동 441-24  NaN  A  카카오  랜드북  나라
# 2           2  녹사평역신축부지32  서울 용산구 이태원동 225-207   90  A  카카오  랜드북  나라
# 3           3        희원빌딩       서울 종로구 경운동 1-9    8  A  카카오  랜드북  나라
# 4           4        대도빌딩       서울 중구 주자동 44-2  NaN  A  카카오  랜드북  나라
#
#                           주변역  입금가(만원)  ...                          고객  \
# 0  디지털미디어시티역(6호선, 공항선, 경의중앙선)  450,000  ...   김진성 701025-1 유연아 780311-2
# 1                    공릉역(7호선)  130,000  ...  최광철 711223-1, 최성례 800107-2
# 2                   녹사평역(6호선)  290,000  ...                황민숙 470307-2
# 3                    안국역(3호선)  490,000  ...                윤인숙 680315-2
# 4              충무로역(3호선, 4호선)  650,000  ...                김정수 370215-2
#
#                     핸드폰  이메일                         회사전화 자택전화   방향  \
# ...

# %%
df4 = pd.read_excel("./준비_.xlsx")
df4.head()
# Out:
#    Unnamed: 0       기본                 주소 상세주소  A   카맵 land  나라  주변역 입금가(만원)  \
# 0           0      NaN  서울 은평구 신사동 19-153  NaN  A  카카오  랜드북  나라  NaN       0
# 1           1    그랜드필드   서울 중구 남산동1가 16-6  NaN  A  카카오  랜드북  나라  NaN       0
# 2           2   라루체웨딩홀   서울 중구 남산동1가 13-6  NaN  A  카카오  랜드북  나라  NaN       0
# 3           3   123호스텔   서울 중구 남산동2가 36-6  NaN  A  카카오  랜드북  나라  NaN       0
# 4           4  오요명동5롯지   서울 중구 남산동2가 33-3  NaN  A  카카오  랜드북  나라  NaN       0
#
#    ...           고객  핸드폰  이메일 회사전화 자택전화   방향                  메모  기타메모 건물특징  \
# 0  ...          NaN  NaN  NaN  NaN  NaN  NaN                 NaN   NaN  NaN
# 1  ...          NaN  NaN  NaN  NaN  NaN  NaN                 NaN   NaN  NaN
# 2  ...    주식회사투데이아트  NaN  NaN  NaN  NaN  NaN                 NaN   NaN  NaN
# 3  ...  성광제620622-1  NaN  NaN  NaN  NaN  NaN  성광제 : 강남구 신사동 청록빌라   NaN  NaN
# 4  ...          NaN  NaN  NaN  NaN  NaN  NaN                 NaN   NaN  NaN
#
#   기타특징
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# ...

# %%
select_feature = [
    '기본', '주소', '상세주소', 'A', '카맵', 'land', '나라', '주변역',
       '입금가(만원)', '기타매매가(만원)', '매매가(만원)', '수익률', '보증금(만원)', '평단가(만원)',
       '월 임대료(만원)', '관리비지출(만원)', '관리비(만원)', '관리비기타(만원)', '대출현황', '지목', '용도지역',
       '토지면적평', '토지면적미터', '미터당 공시지가(원)', '평당 공시지가(만원)', '공시합계(만원)', '도로',
       '사용승인일', '냉난방', '연면적평', '연면적미터', '지하층', '지상층', '승강기', '건폐율', '용적률',
       '주차방식', '주차대수', '고객', '핸드폰', '이메일', '회사전화', '자택전화', '방향', '메모', '기타메모',
       '건물특징', '기타특징'
]

# %%
df1["지목"].unique()
# Out:
# array(['대', '사옥용', '-지목-', 'EV 0 대', '수익용', '2종일반주거지역', '공장용지',
#        '3종일반주거지역', '리모델링용', '주유소용지', '신축부지용도', '주차장', '준공업지역', '1종일반주거지역',
#        'EV 3 대', '일반상업지역', '준주거지역', '병원', '-용도지역-', 'EV 1 대', '잡종지',
#        '목장용지', '1종전용주거지역', '임야', '도로', '공원', '노선상업지역', '전', '종교용지',
#        '근린상업지역', '자연녹지지역', '중심상업지역', '보전녹지지역', '일반공업지역', '답'],
#       dtype=object)

# %%
df1["지목"].value_counts()
# Out:
# 지목
# 대           7378
# -지목-        5346
# EV 0 대      2374
# 수익용          305
# 신축부지용도       161
# 2종일반주거지역     111
# 사옥용           59
# 리모델링용         59
# 3종일반주거지역      44
# 일반상업지역        43
# -용도지역-        20
# 1종일반주거지역      19
# 준주거지역         16
# 자연녹지지역        15
# 주유소용지         12
# 준공업지역         12
# 공장용지          12
# 병원            10
# 주차장            9
# 잡종지            7
# 보전녹지지역         6
# 근린상업지역         6
# 1종전용주거지역       6
# 중심상업지역         5
# 노선상업지역         4
# 종교용지           3
# EV 1 대         2
# 일반공업지역         2
# 전              2
# 임야             2
# EV 3 대         1
# 공원             1
# 도로             1
# 목장용지           1
# 답              1
# Name: count, dtype: int64

# %%
df1["승강기"].value_counts()
# Out:
# 승강기
# EV 0 대     10361
# -승강기-       2378
# EV 1 대      2147
# 개별냉난방        375
# -냉난방-        208
# EV 2 대       171
# 자주식          152
# -주차방식-       140
# EV 3 대        37
# EV 5 대        29
# EV 4 대        23
# 자주식+기계식       19
# 중앙냉난방         11
# 기계식            3
# -              1
# Name: count, dtype: int64

# %%
df2["지목"].unique()
# Out:
# array(['대', '수익용', '사옥용', '신축부지용도', '-지목-', '리모델링용', '공장용지', '주유소용지', '전',
#        '답', '병원', '종교용지', '임야', '잡종지', 'EV 0 대', '주차장', '도로', '철도용지'],
#       dtype=object)

# %%
df2[select_feature].head()
# Out:
#      기본                    주소 상세주소  A   카맵 land  나라                 주변역  \
# 0  송연빌딩       서울 송파구 송파동 89-2  NaN  A  카카오  랜드북  나라       석촌역(8호선, 9호선)
# 1  서경빌딩    서울 성북구 보문동2가 137-1  NaN  A  카카오  랜드북  나라     보문역(6호선, 우이신설선)
# 2   초원빌      서울 성북구 석관동 180-8  NaN  A  카카오  랜드북  나라      석계역 (1호선, 6호선)
# 3  서문빌딩     서울 마포구 서교동 368-22  NaN  A  카카오  랜드북  나라      합정역 (2호선, 6호선)
# 4  장고키친  서울 성동구 성수동1가 668-140  NaN  A  카카오  랜드북  나라  뚝섬역(2호선) 서울숲역(분당선)
#
#      입금가(만원) 기타매매가(만원)  ...                         고객                 핸드폰  \
# 0  1,500,000       NaN  ...               김용진 600719-1   김용진 010-7397-1497
# 1    400,000       NaN  ...               이인완 690819-2   이인완 010-9919-3650
# 2    185,000       NaN  ...               임지현 660909-2   임지현 010-5698-8949
# 3  3,300,000       NaN  ...            주식회사동희 130111-0    사모 010-5471-9622
# 4    700,000       NaN  ...  강원애 481108-2 김지연 740812-2  김지연: 010-8866-5760
#
#              이메일                               회사전화                자택전화  \
# ...

# %%
df3[select_feature].head()
# Out:
#            기본                   주소 상세주소  A   카맵 land  나라  \
# 0       상암바라라      서울 마포구 상암동 1452  NaN  A  카카오  랜드북  나라
# 1   공릉역신축부지16    서울 노원구 공릉동 441-24  NaN  A  카카오  랜드북  나라
# 2  녹사평역신축부지32  서울 용산구 이태원동 225-207   90  A  카카오  랜드북  나라
# 3        희원빌딩       서울 종로구 경운동 1-9    8  A  카카오  랜드북  나라
# 4        대도빌딩       서울 중구 주자동 44-2  NaN  A  카카오  랜드북  나라
#
#                           주변역  입금가(만원)  기타매매가(만원)  ...  \
# 0  디지털미디어시티역(6호선, 공항선, 경의중앙선)  450,000        NaN  ...
# 1                    공릉역(7호선)  130,000        NaN  ...
# 2                   녹사평역(6호선)  290,000        NaN  ...
# 3                    안국역(3호선)  490,000        NaN  ...
# 4              충무로역(3호선, 4호선)  650,000        NaN  ...
#
#                            고객                   핸드폰  이메일  \
# 0   김진성 701025-1 유연아 780311-2     유연아 010-8714-2448  NaN
# 1  최광철 711223-1, 최성례 800107-2     최광철 010-3724-9440  NaN
# 2                황민숙 470307-2  사위 전준형 010-9615-2804  NaN
# ...

# %%
df4[select_feature].head()
# Out:
#         기본                 주소 상세주소  A   카맵 land  나라  주변역 입금가(만원) 기타매매가(만원)  \
# 0      NaN  서울 은평구 신사동 19-153  NaN  A  카카오  랜드북  나라  NaN       0       NaN
# 1    그랜드필드   서울 중구 남산동1가 16-6  NaN  A  카카오  랜드북  나라  NaN       0       NaN
# 2   라루체웨딩홀   서울 중구 남산동1가 13-6  NaN  A  카카오  랜드북  나라  NaN       0       NaN
# 3   123호스텔   서울 중구 남산동2가 36-6  NaN  A  카카오  랜드북  나라  NaN       0       NaN
# 4  오요명동5롯지   서울 중구 남산동2가 33-3  NaN  A  카카오  랜드북  나라  NaN       0       NaN
#
#    ...           고객  핸드폰  이메일 회사전화 자택전화   방향                  메모 기타메모 건물특징  \
# 0  ...          NaN  NaN  NaN  NaN  NaN  NaN                 NaN  NaN  NaN
# 1  ...          NaN  NaN  NaN  NaN  NaN  NaN                 NaN  NaN  NaN
# 2  ...    주식회사투데이아트  NaN  NaN  NaN  NaN  NaN                 NaN  NaN  NaN
# 3  ...  성광제620622-1  NaN  NaN  NaN  NaN  NaN  성광제 : 강남구 신사동 청록빌라  NaN  NaN
# 4  ...          NaN  NaN  NaN  NaN  NaN  NaN                 NaN  NaN  NaN
#
#   기타특징
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# ...

# %%
print(select_feature)


Building_ID : index 


['기본', '주소', '상세주소', 'A', '카맵', 'land', '나라', '주변역', '입금가(만원)', 
'기타매매가(만원)', '매매가(만원)', '수익률', '보증금(만원)', '평단가(만원)', '월 임대료(만원)', 
'관리비지출(만원)', '관리비(만원)', '관리비기타(만원)', '대출현황', '지목', '용도지역', '토지면적평', 
'토지면적미터', '미터당 공시지가(원)', '평당 공시지가(만원)', '공시합계(만원)', '도로', '사용승인일', 
'냉난방', '연면적평', '연면적미터', '지하층', '지상층', '승강기', '건폐율', '용적률', '주차방식', '주차대수', 
'고객', '핸드폰', '이메일', '회사전화', '자택전화', '방향', 


memo : '메모', '기타메모', '건물특징', '기타특징']
# Out:
# ['기본', '주소', '상세주소', 'A', '카맵', 'land', '나라', '주변역', '입금가(만원)', '기타매매가(만원)', '매매가(만원)', '수익률', '보증금(만원)', '평단가(만원)', '월 임대료(만원)', '관리비지출(만원)', '관리비(만원)', '관리비기타(만원)', '대출현황', '지목', '용도지역', '토지면적평', '토지면적미터', '미터당 공시지가(원)', '평당 공시지가(만원)', '공시합계(만원)', '도로', '사용승인일', '냉난방', '연면적평', '연면적미터', '지하층', '지상층', '승강기', '건폐율', '용적률', '주차방식', '주차대수', '고객', '핸드폰', '이메일', '회사전화', '자택전화', '방향', '메모', '기타메모', '건물특징', '기타특징']

# %% [markdown]
# Building_ID
# 1. BD_number : int ( PK )
# 2. register_id_number : int
# 3. create_time : Datetime
# 4. update_time : Datetime
# 5. delete_flag : Boolean
#
#
# Building_info
# 1. BD_number : int ( pk )
# 2. BD_name : str(255) - 건물명
# 3. address : str(255) - 주소
# 4. address_detail : str(255) - 상세주소
# 4. nearby_station : str(255) - 주변역
# 5. deposit_price : int - 입금가
# 6. other_sale_price: int - 기타매매가
# 7. sale_price : int - 매매가
# 8. yield_rate - int 수익률
# 9. security_deposit - int 보증금
# 10. price_per_pyeong - int 평단가
# 11. monthly_rent_fee - int 월 임대료
# 12. maintenance_expense - int 관리비지출
# 13. maintenance_fee - int 관리비
# 14. maintenance_other_fee - int 관리비기타
# 15. loan_status - boolean 대출현황
# 16. land_category - str(255) 지목
# 17. zoning_type - str(255) 용도지역
# 18. land_area_pyeong - int 토지면적평
# 19. land_area_sqm - int 토지면적미터
# 20. official_price_per_sqm_won - int 미터당 공시지가
# 21. official_price_per_pyeong_million - int 평당 공시지가
# 22. official_price_total_million - int 공시합계
# 23. road_access - str(255) 도로
# 24. approval_date - datetime 사용승인일
# 25. heating_cooling - str(255) 냉난방
# 26. gross_area_pyeong - int 연면적평
# 27. gross_area_sqm - int 연면적미터
# 28. underground_floors - int 지하층
# 29. aboveground_floors - int 지상층
# 30. elevator - int 승강기
# 31. building_coverage_ratio - int 건폐율
# 32. floor_area_ratio - int 용적률
# 33. parking_type - str(255) 주차방식
# 34. parking_capacity - int 주차대수
# 35. client_name - str(255) 고객명
# 36. mobile_phone - str(255) 핸드폰
# 37. email - str(255) 이메일
# 38. office_phone - str(255) 회사전화
# 39. home_phone - str(255) 자택전화
# 40. orientation - str(255) 방향
#
#
#
# Building_memo
# 1. BD_number : int(pk)
# 2. loan_status : text
# 2. memo: text
# 3. etc_memo: text
# 4. BD_featrue: text
# 5. etc_featrue: text
# 3. create_time : Datetime
# 4. update_time : Datetime
# 5. delete_flag : Boolean
